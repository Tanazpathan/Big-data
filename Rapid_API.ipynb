# %%
import requests
import pandas as pd

url = "https://free-nba.p.rapidapi.com/players"

querystring = {"page": "0", "per_page": "25"}

headers = {
    "X-RapidAPI-Key": "12d4c64124mshfbf72eb6ce24e35p183d15jsn354ab98aca9e",
    "X-RapidAPI-Host": "free-nba.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Convert JSON response to DataFrame
    data = response.json()
    df = pd.DataFrame(data["data"])
else:
    # Print the error status code and text
    print(f"Error: {response.status_code} - {response.text}")

# %%
df
# Out:
#       id first_name  height_feet  height_inches   last_name position  \
# 0     14        Ike          NaN            NaN    Anigbogu        C
# 1     25        Ron          NaN            NaN       Baker        G
# 2     47     Jabari          NaN            NaN        Bird        G
# 3     67    MarShon          NaN            NaN      Brooks        G
# 4     71    Lorenzo          NaN            NaN       Brown        G
# 5     90       Omri          NaN            NaN      Casspi        F
# 6      1       Alex          6.0            6.0     Abrines        G
# 7    119      Tyler          NaN            NaN       Davis        C
# 8    149     Keenan          NaN            NaN       Evans        G
# 9    179     Marcin          NaN            NaN      Gortat        C
# 10  1593     Andrew          NaN            NaN       Bogut        F
# 11   241       Amir          6.0            9.0     Johnson      C-F
# 12   392    Malachi          NaN            NaN  Richardson        G
# 13   281       Zach          NaN            NaN      Lofton        G
# 14   263      Kosta          7.0            0.0      Koufos        C
# 15   382      Billy          NaN            NaN     Preston        F
# 16   384       Zhou          NaN            NaN          Qi      F-C
# 17   388       Zach          NaN            NaN    Randolph        F
# 18   430         DJ          NaN            NaN    Stephens      G-F
# 19   437      Milos          NaN            NaN    Teodosic        G
# 20   448       Gary          NaN            NaN   Trent Jr.        G
# 21   494    Michael          NaN            NaN       Smith
# 22   495       John          NaN            NaN      Morton
# 23   496     Howard          NaN            NaN      Wright
# 24   497    Michael          NaN            NaN      Ansley
#
#                                                  team  weight_pounds
# 0   {'id': 12, 'abbreviation': 'IND', 'city': 'Ind...            NaN
# 1   {'id': 20, 'abbreviation': 'NYK', 'city': 'New...            NaN
# 2   {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...            NaN
# 3   {'id': 15, 'abbreviation': 'MEM', 'city': 'Mem...            NaN
# 4   {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...            NaN
# 5   {'id': 15, 'abbreviation': 'MEM', 'city': 'Mem...            NaN
# 6   {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...          200.0
# 7   {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...            NaN
# 8   {'id': 9, 'abbreviation': 'DET', 'city': 'Detr...            NaN
# 9   {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...            NaN
# 10  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...            NaN
# 11  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...          240.0
# 12  {'id': 29, 'abbreviation': 'UTA', 'city': 'Uta...            NaN
# 13  {'id': 9, 'abbreviation': 'DET', 'city': 'Detr...            NaN
# 14  {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...          245.0
# 15  {'id': 6, 'abbreviation': 'CLE', 'city': 'Clev...            NaN
# 16  {'id': 11, 'abbreviation': 'HOU', 'city': 'Hou...            NaN
# 17  {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...            NaN
# 18  {'id': 15, 'abbreviation': 'MEM', 'city': 'Mem...            NaN
# 19  {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...            NaN
# 20  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...            NaN
# 21  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...            NaN
# 22  {'id': 6, 'abbreviation': 'CLE', 'city': 'Clev...            NaN
# 23  {'id': 1, 'abbreviation': 'ATL', 'city': 'Atla...            NaN
# 24  {'id': 22, 'abbreviation': 'ORL', 'city': 'Orl...            NaN

# %%
import requests
import pandas as pd

url = "https://planets-info-by-newbapi.p.rapidapi.com/api/v1/planets/"

headers = {
    "X-RapidAPI-Key": "12d4c64124mshfbf72eb6ce24e35p183d15jsn354ab98aca9e",
    "X-RapidAPI-Host": "planets-info-by-newbapi.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Convert JSON response to DataFrame
    data = response.json()
    df = pd.DataFrame(data)
else:
    print(f"Error: {response.status_code} - {response.text}")

# %%
df
# Out:
#    planetOrder     name                                        description  \
# 0            1  Mercury  Mercury is the smallest planet in the Solar Sy...
# 1            2    Venus  Venus is the second planet from the Sun and is...
# 2            3    Earth  Earth is the third planet from the Sun and the...
# 3            4     Mars  Mars is the fourth planet from the Sun and the...
# 4            5  Jupiter  Jupiter is the fifth planet from the Sun and t...
# 5            6   Saturn  Saturn is the sixth planet from the Sun and th...
# 6            7   Uranus  Uranus is the seventh planet from the Sun. Its...
# 7            8  Neptune  Neptune is the eighth and farthest-known Solar...
#
#                                         basicDetails     source  \
# 0  {'volume': '6.083 x 10^10 km^3', 'mass': '3.30...  Wikipedia
# 1  {'volume': '9.2843 x 10^11 km^3', 'mass': '4.8...  Wikipedia
# 2  {'volume': '1.08321 x 1012 km3', 'mass': '5.97...  Wikipedia
# 3  {'volume': '1.63118 x 10^11 km^3', 'mass': '6....  Wikipedia
# 4  {'volume': '1.4313 x 10^15 km^3', 'mass': '1.8...  Wikipedia
# 5  {'volume': '8.2713 x 10^14 km^3', 'mass': '8.2...  Wikipedia
# 6  {'volume': '6.833 x 1013 km^3', 'mass': '(8.68...  Wikipedia
# 7  {'volume': '6.253 x 1013 km^3', 'mass': '1.024...  Wikipedia
#
#                                          wikiLink  \
# 0  https://en.wikipedia.org/wiki/Mercury_(planet)
# 1             https://en.wikipedia.org/wiki/Venus
# 2             https://en.wikipedia.org/wiki/Earth
# 3              https://en.wikipedia.org/wiki/Mars
# 4           https://en.wikipedia.org/wiki/Jupiter
# 5            https://en.wikipedia.org/wiki/Saturn
# 6            https://en.wikipedia.org/wiki/Uranus
# 7           https://en.wikipedia.org/wiki/Neptune
#
#                                               imgSrc  id
# 0  {'img': 'https://upload.wikimedia.org/wikipedi...   1
# 1  {'img': 'https://upload.wikimedia.org/wikipedi...   2
# 2  {'img': 'https://upload.wikimedia.org/wikipedi...   3
# 3  {'img': 'https://upload.wikimedia.org/wikipedi...   4
# 4  {'img': 'https://upload.wikimedia.org/wikipedi...   5
# 5  {'img': 'https://upload.wikimedia.org/wikipedi...   6
# 6  {'img': 'https://upload.wikimedia.org/wikipedi...   7
# 7  {'img': 'https://upload.wikimedia.org/wikipedi...   8
